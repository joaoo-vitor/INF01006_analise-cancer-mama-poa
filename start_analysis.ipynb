# %%
import pandas as pd

df_siscam = pd.read_csv('../../SISCAN_MAMOGRAFIA_PACNT_2024.csv', sep=';', engine='python')
df_siscam.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df_siscam = pd.read_csv('../../SISCAN_MAMOGRAFIA_PACNT_2024.csv', sep=';', engine='python')
#       4 df_siscam.head()
#
# File c:\Users\joaoo\.virtualenvs\cancer-mama-poa-pveCVcl5\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_menor = df_siscam.head(100)
df_menor.to_csv("SISCAN_MAMO_PACNT_MENOR.csv", sep=";", index=False)

# %%
df_siscam['CO_ESCOLARIDADE'].unique()
# Out:
# array([nan])

# %%
import pandas as pd
df_mamografias_normal = pd.read_csv(r"c:\Users\joaoo\Desktop\SISCAN_MAMOGRAFIA_2024.csv", sep=";", engine="python")
df_mamografias_normal.head(200).to_csv("SISCAN_MAMOGRAFIA_2024_MENOR.CSV", sep=";")

# %%
df_mamografias_normal.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3618666 entries, 0 to 3618665
# Data columns (total 82 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   CO_SEQ_SISCAN_MAMOGRAFIA_RESID  int64
#  1   CO_UF_UNIDADE_SAUDE             float64
#  2   CO_UF_RESIDENCIA                int64
#  3   CO_UF_PREST_SERVICO             float64
#  4   CO_MUN_UNIDADE_SAUDE            float64
#  5   CO_MUN_RESIDENCIA               int64
#  6   CO_MUN_PREST_SERVICO            float64
#  7   CO_UNIDADE_SAUDE                float64
#  8   CO_PREST_SERVICO                float64
#  9   NU_ANO_COMPETENCIA              int64
#  10  NU_ANO_MES_COMPETENCIA          int64
#  11  CO_RACA_COR                     int64
#  12  CO_ETNIA                        str
#  13  CO_IDADE_PACIENTE               int64
#  14  CO_ESCOLARIDADE                 float64
#  15  TP_RESP_APRES_RISC_ELEV_CANCER  float64
#  16  TP_RESP_ANT_MAMA_EXA_PROF_SAUD  int64
# ...
